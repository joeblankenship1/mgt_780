# %% [markdown]
# # Installation Exercise

# %% [markdown]
# In this exercise, we will install Python 3, Jupyter Notebooks, and the libraries required to complete the exercises throughout this course.
#
# If there are issues at any time with the content, please submit issues on GitHub.

# %% [markdown]
# ## Installing Python 3

# %% [markdown]
# At the time of writing this, there are two Pythons: Legacy Python (2.x) and Python (3.x). In 2020, legacy Python will no longer be supported by the large Python community. It is with this in mind that we will be using Python 3 for these exercises.

# %% [markdown]
# ## Installing Jupyter Notebooks

# %% [markdown]
# ## Installing Support Libraries

# %% [markdown]
# NetworkX, Numpy, SciPy, Pandas

# %% [markdown]
# ## Test Exercise

# %% [markdown]
# Upload data, analyze data frame, visualize network

# %% [markdown]
# ### Import libraries

# %%
# import our libraries for analysis
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline

# %% [markdown]
# ### Import, Analyze, Modify our CSV files

# %%
# create dataframes from our CSV files
padgm = pd.read_csv('data/padgm.csv', index_col=0)

# show the padgm dataframe we just created
padgm
# Out:
#               ACCIAIUOLI  ALBIZZI  BARBADORI  BISCHERI  CASTELLANI  GINORI  \
# ID
# ACCIAIUOLI             0        0          0         0           0       0
# ALBIZZI                0        0          0         0           0       1
# BARBADORI              0        0          0         0           1       0
# BISCHERI               0        0          0         0           0       0
# CASTELLANI             0        0          1         0           0       0
# GINORI                 0        1          0         0           0       0
# GUADAGNI               0        1          0         1           0       0
# LAMBERTESCHI           0        0          0         0           0       0
# MEDICI                 1        1          1         0           0       0
# PAZZI                  0        0          0         0           0       0
# PERUZZI                0        0          0         1           1       0
# ...

# %%
# show descriptive stats for the padgm dataframe
padgm.describe(include='all')
# Out:
#        ACCIAIUOLI    ALBIZZI  BARBADORI   BISCHERI  CASTELLANI   GINORI  \
# count     16.0000  16.000000  16.000000  16.000000   16.000000  16.0000
# mean       0.0625   0.187500   0.125000   0.187500    0.187500   0.0625
# std        0.2500   0.403113   0.341565   0.403113    0.403113   0.2500
# min        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# 25%        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# 50%        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# 75%        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# max        1.0000   1.000000   1.000000   1.000000    1.000000   1.0000
#
#         GUADAGNI  LAMBERTESCHI  MEDICI    PAZZI    PERUZZI  PUCCI    RIDOLFI  \
# count  16.000000       16.0000  16.000  16.0000  16.000000   16.0  16.000000
# mean    0.250000        0.0625   0.375   0.0625   0.187500    0.0   0.187500
# std     0.447214        0.2500   0.500   0.2500   0.403113    0.0   0.403113
# ...

# %%
# create dataframes from our CSV files
padgb = pd.read_csv('data/padgb.csv', index_col=0)

# show the padgb dataframe we just created
padgb
# Out:
#               ACCIAIUOLI  ALBIZZI  BARBADORI  BISCHERI  CASTELLANI  GINORI  \
# ID
# ACCIAIUOLI             0        0          0         0           0       0
# ALBIZZI                0        0          0         0           0       0
# BARBADORI              0        0          0         0           1       1
# BISCHERI               0        0          0         0           0       0
# CASTELLANI             0        0          1         0           0       0
# GINORI                 0        0          1         0           0       0
# GUADAGNI               0        0          0         1           0       0
# LAMBERTESCHI           0        0          0         1           1       0
# MEDICI                 0        0          1         0           0       1
# PAZZI                  0        0          0         0           0       0
# PERUZZI                0        0          1         1           1       0
# ...

# %%
# show descriptive stats for the padgb dataframe
padgb.describe(include='all')
# Out:
#        ACCIAIUOLI  ALBIZZI  BARBADORI   BISCHERI  CASTELLANI     GINORI  \
# count        16.0     16.0  16.000000  16.000000   16.000000  16.000000
# mean          0.0      0.0   0.250000   0.187500    0.187500   0.125000
# std           0.0      0.0   0.447214   0.403113    0.403113   0.341565
# min           0.0      0.0   0.000000   0.000000    0.000000   0.000000
# 25%           0.0      0.0   0.000000   0.000000    0.000000   0.000000
# 50%           0.0      0.0   0.000000   0.000000    0.000000   0.000000
# 75%           0.0      0.0   0.250000   0.000000    0.000000   0.000000
# max           0.0      0.0   1.000000   1.000000    1.000000   1.000000
#
#         GUADAGNI  LAMBERTESCHI     MEDICI    PAZZI    PERUZZI  PUCCI  RIDOLFI  \
# count  16.000000     16.000000  16.000000  16.0000  16.000000   16.0     16.0
# mean    0.125000      0.250000   0.312500   0.0625   0.250000    0.0      0.0
# std     0.341565      0.447214   0.478714   0.2500   0.447214    0.0      0.0
# ...

# %% [markdown]
# ### Visualizing a network

# %%
# create a graph object
# give it our dataframe
G = nx.Graph(padgm.values)

# %%
# render the graph
# a new window will pop-up with the graph
nx.draw_networkx(G)
# Out:
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_pylab.py:724: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(label):

# %% [markdown]
# ### Modify data

# %%
# to change a value in table
# select the row, column of our dataframe
# set it = to a new value
padgm.loc['MEDICI', 'ACCIAIUOLI'] = 0
padgm
# Out:
#               ACCIAIUOLI  ALBIZZI  BARBADORI  BISCHERI  CASTELLANI  GINORI  \
# ID
# ACCIAIUOLI             0        0          0         0           0       0
# ALBIZZI                0        0          0         0           0       1
# BARBADORI              0        0          0         0           1       0
# BISCHERI               0        0          0         0           0       0
# CASTELLANI             0        0          1         0           0       0
# GINORI                 0        1          0         0           0       0
# GUADAGNI               0        1          0         1           0       0
# LAMBERTESCHI           0        0          0         0           0       0
# MEDICI                 0        1          1         0           0       0
# PAZZI                  0        0          0         0           0       0
# PERUZZI                0        0          0         1           1       0
# ...

# %% [markdown]
# # Installation Exercise

# %% [markdown]
# In this exercise, we will install Python 3, Jupyter Notebooks, and the libraries required to complete the exercises throughout this course.
#
# If there are issues at any time with the content, please submit issues on GitHub.

# %% [markdown]
# ## Installing Python 3

# %% [markdown]
# At the time of writing this, there are two Pythons: Legacy Python (2.x) and Python (3.x). In 2020, legacy Python will no longer be supported by the large Python community. It is with this in mind that we will be using Python 3.6+ for these exercises.

# %% [markdown]
# If you are doing this on a Mac or Linux machine, you may already have Python3 installed. Open your terminal and type these commands to check which versions are on your system:

# %% [markdown]
# ```python
# python --version
#
# python3 --version
# ```

# %% [markdown]
# The one you want to use is Python 3.6 or higher.

# %% [markdown]
# If you do not have Python 3 on your system, go here and follow the directions for installation:
# [https://www.python.org/downloads/](https://www.python.org/downloads/)

# %% [markdown]
# ## Installing Jupyter Lab

# %% [markdown]
# In the past, I would have recommmended installing iPython, Spyder, or Jupyter Notebooks; but why would you do that when you can have all three!

# %% [markdown]
# If Python 3 is installed successfully on your system, then you can simply `pip install` Jupyter Lab

# %% [markdown]
# ```python
# pip install jupyterlab # may require sudo for install if not in virtual environment
# ```

# %% [markdown]
# Find out more about [Jupyter Lab](https://github.com/jupyterlab/jupyterlab)

# %% [markdown]
# ## Installing Support Libraries

# %% [markdown]
# Throughout this course, we may install additional libraries, but for now we will be installing the ones we'll be revisting most: Numpy, Pandas, and NetworkX.

# %% [markdown]
# ```python
# pip install numpy pandas networkx # may require sudo
# ```

# %% [markdown]
# Find out more about [NumPy](http://www.numpy.org/), [Pandas](https://pandas.pydata.org/), [NetworkX](https://networkx.github.io/documentation/stable/#)

# %% [markdown]
# ## Test Exercise

# %% [markdown]
# Now we'll test out some of the basics by uploading data, analyzing the data we import, and visualize a simple network.

# %% [markdown]
# ### Import libraries

# %%
# import our libraries for analysis
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from nxviz import MatrixPlot, ArcPlot, CircosPlot
# %matplotlib inline

# %% [markdown]
# ### Import and Analyze our CSV files

# %%
# create dataframes from our CSV files
padgm = pd.read_csv('data/padgm.csv', index_col=0)

# show the padgm dataframe we just created
padgm
# Out:
#               ACCIAIUOLI  ALBIZZI  BARBADORI  BISCHERI  CASTELLANI  GINORI  \
# ID
# ACCIAIUOLI             0        0          0         0           0       0
# ALBIZZI                0        0          0         0           0       1
# BARBADORI              0        0          0         0           1       0
# BISCHERI               0        0          0         0           0       0
# CASTELLANI             0        0          1         0           0       0
# GINORI                 0        1          0         0           0       0
# GUADAGNI               0        1          0         1           0       0
# LAMBERTESCHI           0        0          0         0           0       0
# MEDICI                 1        1          1         0           0       0
# PAZZI                  0        0          0         0           0       0
# PERUZZI                0        0          0         1           1       0
# PUCCI                  0        0          0         0           0       0
# RIDOLFI                0        0          0         0           0       0
# SALVIATI               0        0          0         0           0       0
# STROZZI                0        0          0         1           1       0
# TORNABUONI             0        0          0         0           0       0
#
#               GUADAGNI  LAMBERTESCHI  MEDICI  PAZZI  PERUZZI  PUCCI  RIDOLFI  \
# ID
# ACCIAIUOLI           0             0       1      0        0      0        0
# ALBIZZI              1             0       1      0        0      0        0
# BARBADORI            0             0       1      0        0      0        0
# BISCHERI             1             0       0      0        1      0        0
# CASTELLANI           0             0       0      0        1      0        0
# GINORI               0             0       0      0        0      0        0
# GUADAGNI             0             1       0      0        0      0        0
# LAMBERTESCHI         1             0       0      0        0      0        0
# MEDICI               0             0       0      0        0      0        1
# PAZZI                0             0       0      0        0      0        0
# PERUZZI              0             0       0      0        0      0        0
# PUCCI                0             0       0      0        0      0        0
# RIDOLFI              0             0       1      0        0      0        0
# SALVIATI             0             0       1      1        0      0        0
# STROZZI              0             0       0      0        1      0        1
# TORNABUONI           1             0       1      0        0      0        1
#
#               SALVIATI  STROZZI  TORNABUONI
# ID
# ACCIAIUOLI           0        0           0
# ALBIZZI              0        0           0
# BARBADORI            0        0           0
# BISCHERI             0        1           0
# CASTELLANI           0        1           0
# GINORI               0        0           0
# GUADAGNI             0        0           1
# LAMBERTESCHI         0        0           0
# MEDICI               1        0           1
# PAZZI                1        0           0
# PERUZZI              0        1           0
# PUCCI                0        0           0
# RIDOLFI              0        1           1
# SALVIATI             0        0           0
# STROZZI              0        0           0
# TORNABUONI           0        0           0

# %%
# show descriptive stats for the padgm dataframe
padgm.describe(include='all')
# Out:
#        ACCIAIUOLI    ALBIZZI  BARBADORI   BISCHERI  CASTELLANI   GINORI  \
# count     16.0000  16.000000  16.000000  16.000000   16.000000  16.0000
# mean       0.0625   0.187500   0.125000   0.187500    0.187500   0.0625
# std        0.2500   0.403113   0.341565   0.403113    0.403113   0.2500
# min        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# 25%        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# 50%        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# 75%        0.0000   0.000000   0.000000   0.000000    0.000000   0.0000
# max        1.0000   1.000000   1.000000   1.000000    1.000000   1.0000
#
#         GUADAGNI  LAMBERTESCHI  MEDICI    PAZZI    PERUZZI  PUCCI    RIDOLFI  \
# count  16.000000       16.0000  16.000  16.0000  16.000000   16.0  16.000000
# mean    0.250000        0.0625   0.375   0.0625   0.187500    0.0   0.187500
# std     0.447214        0.2500   0.500   0.2500   0.403113    0.0   0.403113
# min     0.000000        0.0000   0.000   0.0000   0.000000    0.0   0.000000
# 25%     0.000000        0.0000   0.000   0.0000   0.000000    0.0   0.000000
# 50%     0.000000        0.0000   0.000   0.0000   0.000000    0.0   0.000000
# 75%     0.250000        0.0000   1.000   0.0000   0.000000    0.0   0.000000
# max     1.000000        1.0000   1.000   1.0000   1.000000    0.0   1.000000
#
#         SALVIATI    STROZZI  TORNABUONI
# count  16.000000  16.000000   16.000000
# mean    0.125000   0.250000    0.187500
# std     0.341565   0.447214    0.403113
# min     0.000000   0.000000    0.000000
# 25%     0.000000   0.000000    0.000000
# 50%     0.000000   0.000000    0.000000
# 75%     0.000000   0.250000    0.000000
# max     1.000000   1.000000    1.000000

# %%
# create dataframes from our CSV files
padgb = pd.read_csv('data/padgb.csv', index_col=0)

# mean    0.125000      0.250000   0.312500   0.0625   0.250000    0.0      0.0
# std     0.341565      0.447214   0.478714   0.2500   0.447214    0.0      0.0
# min     0.000000      0.000000   0.000000   0.0000   0.000000    0.0      0.0
# 25%     0.000000      0.000000   0.000000   0.0000   0.000000    0.0      0.0
# 50%     0.000000      0.000000   0.000000   0.0000   0.000000    0.0      0.0
# 75%     0.000000      0.250000   1.000000   0.0000   0.250000    0.0      0.0
# max     1.000000      1.000000   1.000000   1.0000   1.000000    0.0      0.0
#
#        SALVIATI  STROZZI  TORNABUONI
# count   16.0000     16.0     16.0000
# mean     0.0625      0.0      0.0625
# std      0.2500      0.0      0.2500
# min      0.0000      0.0      0.0000
# 25%      0.0000      0.0      0.0000
# 50%      0.0000      0.0      0.0000
# 75%      0.0000      0.0      0.0000
# max      1.0000      0.0      1.0000

# %% [markdown]
# ### Visualizing a network

# %%
# create a graph object
# give it our dataframe values as a numpy array
graph_padgm = nx.DiGraph(padgm.values)

# %%
# create a list of names from our dataframe index
names = list(padgm.index)
# create a list of k:v pairs for node degree
degree = nx.degree(graph_padgm)

# for each node in our node list
for i in graph_padgm.nodes:
    # add a name attribute from the names list if it equal our node value
    graph_padgm.add_node(i, name=names[i])
    # add a degree attribute from the degree list if it equals our node value
    graph_padgm.add_node(i, degree=degree[i])

# %%
# show out nodes with all metadata
list(graph_padgm.nodes(data=True))
# Out:
# [(0, {'degree': 2, 'name': 'ACCIAIUOLI'}),
#  (1, {'degree': 6, 'name': 'ALBIZZI'}),
#  (2, {'degree': 4, 'name': 'BARBADORI'}),
#  (3, {'degree': 6, 'name': 'BISCHERI'}),
#  (4, {'degree': 6, 'name': 'CASTELLANI'}),
#  (5, {'degree': 2, 'name': 'GINORI'}),
#  (6, {'degree': 8, 'name': 'GUADAGNI'}),
#  (7, {'degree': 2, 'name': 'LAMBERTESCHI'}),
#  (8, {'degree': 12, 'name': 'MEDICI'}),
#  (9, {'degree': 2, 'name': 'PAZZI'}),
#  (10, {'degree': 6, 'name': 'PERUZZI'}),
#  (11, {'degree': 0, 'name': 'PUCCI'}),
#  (12, {'degree': 6, 'name': 'RIDOLFI'}),
#  (13, {'degree': 4, 'name': 'SALVIATI'}),
#  (14, {'degree': 8, 'name': 'STROZZI'}),
#  (15, {'degree': 6, 'name': 'TORNABUONI'})]

# %%
# Show the first 5 edges in our edge list
list(graph_padgm.edges())[0:5]
# Out:
# [(0, 8), (1, 8), (1, 5), (1, 6), (2, 8)]

# %%
# render the force gravity graph
# arrow and labels will be shown
# mulitple the value of each degree value by 100 from out node metadata
# a new window will pop-up with the graph
nx.draw_kamada_kawai(graph_padgm, arrows=True, with_labels=True, node_size=[v * 100 for v in dict(graph_padgm.nodes.data('degree')).values()])

# %%
# create a circos plot for padgm with nodes colored and ordered by degree
# highest to lowest degree from purple going clockwise
padgm_circos = CircosPlot(graph_padgm, node_color='degree', node_order='degree')
padgm_circos.draw()

# %%
# Create an arcplot for padgm with nodes colored and ordered by degree
# highest to lowest degree from purple going right to left
padgm_arc = ArcPlot(graph_padgm, node_order='degree', node_color='degree')
padgm_arc.draw()

# %%
# Now lets do the same thing for padgb
graph_padgb = nx.DiGraph(padgb.values)

names = list(padgb.index)
degree = nx.degree(graph_padgb)

for i in graph_padgb.nodes:
    graph_padgb.add_node(i, name=names[i])
    graph_padgb.add_node(i, degree=degree[i])

nx.draw_kamada_kawai(graph_padgb, arrows=True, with_labels=True, node_size=[v * 100 for v in dict(graph_padgb.nodes.data('degree')).values()])

# %%
padgb_circos = CircosPlot(graph_padgb, node_color='degree', node_order='degree')
padgb_circos.draw()

# %%
padgb_arc = ArcPlot(graph_padgb, node_order='degree', node_color='degree')
padgb_arc.draw()

# %% [markdown]
# ### Modify our Data

# %%
# to change a value in table
# select the row, column of our dataframe
# set it = to a new value
padgm.loc['MEDICI', 'ACCIAIUOLI'] = 0
padgm
# Out:
#               ACCIAIUOLI  ALBIZZI  BARBADORI  BISCHERI  CASTELLANI  GINORI  \
# ID
# ACCIAIUOLI             0        0          0         0           0       0
# ALBIZZI                0        0          0         0           0       1
# BARBADORI              0        0          0         0           1       0
# BISCHERI               0        0          0         0           0       0
# CASTELLANI             0        0          1         0           0       0
# GINORI                 0        1          0         0           0       0
# GUADAGNI               0        1          0         1           0       0
# LAMBERTESCHI           0        0          0         0           0       0
# MEDICI                 0        1          1         0           0       0
# PAZZI                  0        0          0         0           0       0
# PERUZZI                0        0          0         1           1       0
# PUCCI                  0        0          0         0           0       0
# RIDOLFI                0        0          0         0           0       0
# SALVIATI               0        0          0         0           0       0
# STROZZI                0        0          0         1           1       0
# TORNABUONI             0        0          0         0           0       0
#
#               GUADAGNI  LAMBERTESCHI  MEDICI  PAZZI  PERUZZI  PUCCI  RIDOLFI  \
# ID
# ACCIAIUOLI           0             0       1      0        0      0        0
# ALBIZZI              1             0       1      0        0      0        0
# BARBADORI            0             0       1      0        0      0        0
# BISCHERI             1             0       0      0        1      0        0
# CASTELLANI           0             0       0      0        1      0        0
# GINORI               0             0       0      0        0      0        0
# GUADAGNI             0             1       0      0        0      0        0
# LAMBERTESCHI         1             0       0      0        0      0        0
# MEDICI               0             0       0      0        0      0        1
# PAZZI                0             0       0      0        0      0        0
# PERUZZI              0             0       0      0        0      0        0
# PUCCI                0             0       0      0        0      0        0
# RIDOLFI              0             0       1      0        0      0        0
# SALVIATI             0             0       1      1        0      0        0
# STROZZI              0             0       0      0        1      0        1
# TORNABUONI           1             0       1      0        0      0        1
#
#               SALVIATI  STROZZI  TORNABUONI
# ID
# ACCIAIUOLI           0        0           0
# ALBIZZI              0        0           0
# BARBADORI            0        0           0
# BISCHERI             0        1           0
# CASTELLANI           0        1           0
# GINORI               0        0           0
# GUADAGNI             0        0           1
# LAMBERTESCHI         0        0           0
# MEDICI               1        0           1
# PAZZI                1        0           0
# PERUZZI              0        1           0
# PUCCI                0        0           0
# RIDOLFI              0        1           1
# SALVIATI             0        0           0
# STROZZI              0        0           0
# TORNABUONI           0        0           0
